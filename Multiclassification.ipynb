# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhava-123/dllab/blob/main/Multiclassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
import numpy as np
from keras.utils import to_categorical

def OneHotEncoding_fn(ReutersData, dimension=10000):
    # 8982 x 10k matrix of zeros
    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):
        #Selectively make indices as 1 based on availability of word in the review.
        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data

x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]


model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 3s 115ms/step - loss: 2.9380 - categorical_accuracy: 0.4735 - val_loss: 1.9990 - val_categorical_accuracy: 0.6375
# Epoch 2/25
# 16/16 [==============================] - 1s 63ms/step - loss: 1.6413 - categorical_accuracy: 0.6797 - val_loss: 1.3965 - val_categorical_accuracy: 0.6913
# Epoch 3/25
# 16/16 [==============================] - 1s 47ms/step - loss: 1.2115 - categorical_accuracy: 0.7337 - val_loss: 1.1951 - val_categorical_accuracy: 0.7362
# Epoch 4/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.9878 - categorical_accuracy: 0.7877 - val_loss: 1.0912 - val_categorical_accuracy: 0.7738
# Epoch 5/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.8244 - categorical_accuracy: 0.8241 - val_loss: 1.0164 - val_categorical_accuracy: 0.7812
# Epoch 6/25
# 16/16 [==============================] - 1s 47ms/step - loss: 0.6844 - categorical_accuracy: 0.8525 - val_loss: 0.9742 - val_categorical_accuracy: 0.7912
# Epoch 7/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.5766 - categorical_accuracy: 0.8729 - val_loss: 0.9244 - val_categorical_accuracy: 0.8012
# Epoch 8/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.4837 - categorical_accuracy: 0.8964 - val_loss: 0.9002 - val_categorical_accuracy: 0.8075
# Epoch 9/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.4078 - categorical_accuracy: 0.9129 - val_loss: 0.8944 - val_categorical_accuracy: 0.8037
# Epoch 10/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.3453 - categorical_accuracy: 0.9267 - val_loss: 0.8779 - val_categorical_accuracy: 0.8112
# Epoch 11/25
# 16/16 [==============================] - 1s 47ms/step - loss: 0.2958 - categorical_accuracy: 0.9349 - val_loss: 0.8765 - val_categorical_accuracy: 0.8112
# Epoch 12/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.2592 - categorical_accuracy: 0.9413 - val_loss: 0.8920 - val_categorical_accuracy: 0.8138
# Epoch 13/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.2330 - categorical_accuracy: 0.9456 - val_loss: 0.8945 - val_categorical_accuracy: 0.8112
# Epoch 14/25
# 16/16 [==============================] - 1s 47ms/step - loss: 0.2069 - categorical_accuracy: 0.9495 - val_loss: 0.9287 - val_categorical_accuracy: 0.8112
# Epoch 15/25
# 16/16 [==============================] - 1s 76ms/step - loss: 0.1914 - categorical_accuracy: 0.9515 - val_loss: 0.9249 - val_categorical_accuracy: 0.8087
# Epoch 16/25
# 16/16 [==============================] - 1s 82ms/step - loss: 0.1728 - categorical_accuracy: 0.9525 - val_loss: 0.9438 - val_categorical_accuracy: 0.8150
# Epoch 17/25
# 16/16 [==============================] - 1s 66ms/step - loss: 0.1621 - categorical_accuracy: 0.9559 - val_loss: 0.9618 - val_categorical_accuracy: 0.8112
# Epoch 18/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1509 - categorical_accuracy: 0.9553 - val_loss: 0.9390 - val_categorical_accuracy: 0.8125
# Epoch 19/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1457 - categorical_accuracy: 0.9544 - val_loss: 0.9699 - val_categorical_accuracy: 0.8087
# Epoch 20/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1343 - categorical_accuracy: 0.9559 - val_loss: 0.9757 - val_categorical_accuracy: 0.8062
# Epoch 21/25
# 16/16 [==============================] - 1s 46ms/step - loss: 0.1316 - categorical_accuracy: 0.9582 - val_loss: 0.9828 - val_categorical_accuracy: 0.8200
# Epoch 22/25
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1250 - categorical_accuracy: 0.9575 - val_loss: 1.0032 - val_categorical_accuracy: 0.8163
# Epoch 23/25
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1288 - categorical_accuracy: 0.9553 - val_loss: 1.0703 - val_categorical_accuracy: 0.7912
# Epoch 24/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1197 - categorical_accuracy: 0.9560 - val_loss: 1.0188 - val_categorical_accuracy: 0.8150
# Epoch 25/25
# 16/16 [==============================] - 1s 45ms/step - loss: 0.1158 - categorical_accuracy: 0.9573 - val_loss: 1.0546 - val_categorical_accuracy: 0.8075

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
